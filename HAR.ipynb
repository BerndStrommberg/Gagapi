# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tidy_dataset - training.csv')

# %%
df.head(20)
# Out:
#     tbodyaccmeanx  tbodyaccmeany  tbodyaccmeanz  tgravityaccmeanx  \
# 1        0.282022      -0.037696      -0.134897          0.945303
# 2        0.255841      -0.064550      -0.095186          0.941113
# 3        0.254867       0.003815      -0.123658          0.946364
# 4        0.343370      -0.014446      -0.167377          0.952445
# 5        0.276240      -0.029638      -0.142616          0.947125
# 6        0.255468       0.021219      -0.048949          0.945749
# 7        0.321140       0.001582      -0.043554          0.950212
# 8        0.234666      -0.049548      -0.111757          0.949130
# 9        0.312634      -0.026368      -0.130951          0.946917
# 10       0.276915      -0.035486      -0.080569          0.946870
# 11       0.205307      -0.008508      -0.119647          0.945419
# 12       0.306996      -0.013787      -0.180162          0.941937
# 13       0.281513      -0.040801      -0.134675          0.937468
# 14       0.303885       0.002768      -0.038613          0.937195
# 15       0.354193      -0.012561      -0.058681          0.947823
# 16       0.222298      -0.018660      -0.117186          0.957365
# 17       0.214481       0.009939      -0.123073          0.954731
# 18       0.327317      -0.022256      -0.149144          0.945028
# 19       0.349059      -0.022004      -0.150052          0.943344
# 20       0.264682      -0.008592      -0.102974          0.948648
#
#     tgravityaccmeany  tgravityaccmeanz  tbodyaccjerkmeanx  tbodyaccjerkmeany  \
# 1          -0.245941         -0.032165          -0.156486          -0.142853
# 2          -0.252035         -0.032883          -0.207554           0.357843
# 3          -0.264278         -0.025575           0.201604           0.417082
# 4          -0.259838         -0.026131           0.336085          -0.464144
# 5          -0.257100         -0.028423          -0.235623          -0.111777
# 6          -0.254778         -0.026521           0.115930           0.234667
# 7          -0.244830         -0.023628           0.304833          -0.094993
# 8          -0.236905         -0.022201          -0.209168           0.175005
# 9          -0.262056         -0.020236          -0.094395           0.013017
# 10         -0.255801         -0.035628          -0.174054          -0.044309
# 11         -0.254668         -0.032058           0.314329          -0.037261
# 12         -0.255759         -0.026833           0.467070          -0.379215
# 13         -0.258400         -0.034867          -0.233326           0.026585
# 14         -0.266212         -0.034423           0.019033           0.074249
# 15         -0.265399         -0.030586           0.165117          -0.250474
# 16         -0.258512         -0.030633          -0.241611           0.446472
# 17         -0.254213         -0.027618           0.407987           0.367825
# 18         -0.251478         -0.024246           0.398624          -0.345001
# 19         -0.244003         -0.020724          -0.168555           0.011977
# 20         -0.234382         -0.018603          -0.343985           0.180771
#
#     tbodyaccjerkmeanz  tbodygyromeanx    ...     fbodyaccjerkmeanz  \
# 1           -0.113079       -0.479730    ...             -0.535709
# 2           -0.452401        0.094091    ...             -0.498948
# 3            0.139078        0.211201    ...             -0.525648
# 4           -0.005026        0.096082    ...             -0.487423
# 5            0.172655        0.008742    ...             -0.425895
# 6            0.361505       -0.042557    ...             -0.433487
# 7           -0.362395       -0.037247    ...             -0.456496
# 8           -0.420422       -0.016109    ...             -0.435391
# 9           -0.305795       -0.239286    ...             -0.562728
# 10          -0.316509       -0.070739    ...             -0.453717
# 11          -0.108589        0.012781    ...             -0.476938
# 12          -0.126807       -0.019692    ...             -0.499537
# 13           0.340662       -0.049202    ...             -0.457586
# 14           0.295786       -0.017927    ...             -0.395313
# 15          -0.262534       -0.011482    ...             -0.380833
# 16          -0.094830        0.012997    ...             -0.424844
# 17          -0.123016        0.014652    ...             -0.438019
# 18          -0.162696       -0.045532    ...             -0.452224
# 19           0.086308       -0.068353    ...             -0.472157
# 20           0.318332       -0.065824    ...             -0.490792
#
#     fbodygyromeanx  fbodygyromeany  fbodygyromeanz  fbodyaccmagmean  \
# 1        -0.184781       -0.198024       -0.307558        -0.166811
# 2        -0.204510       -0.245831       -0.311178        -0.079278
# 3        -0.317082       -0.208159       -0.185798        -0.156313
# 4        -0.162211        0.026553       -0.180469        -0.104377
# 5        -0.237106        0.047211       -0.257958        -0.123195
# 6        -0.347535       -0.035160       -0.333846        -0.200025
# 7        -0.395905       -0.146166       -0.276226        -0.148472
# 8        -0.320083       -0.106937       -0.224305        -0.110827
# 9        -0.327680       -0.257786       -0.356219        -0.258717
# 10       -0.293154       -0.186979       -0.285352        -0.163224
# 11       -0.378329       -0.245780       -0.287402        -0.222277
# 12       -0.397887       -0.040889       -0.250036        -0.151677
# 13       -0.404899       -0.064843       -0.275699        -0.150976
# 14       -0.360945       -0.028598       -0.191220        -0.075130
# 15       -0.387269       -0.120557       -0.187585        -0.059139
# 16       -0.365932       -0.152855       -0.163620        -0.129877
# 17       -0.292596       -0.102789       -0.242377        -0.115335
# 18       -0.264768       -0.006821       -0.170788        -0.114925
# 19       -0.336393        0.062869       -0.129342        -0.143827
# 20       -0.396208       -0.047367       -0.158925        -0.197116
#
#     fbodybodyaccjerkmagmean  fbodybodygyromagmean  fbodybodygyrojerkmagmean  \
# 1                 -0.154045             -0.222176                 -0.431832
# 2                 -0.178446             -0.268280                 -0.428186
# 3                 -0.149438             -0.308671                 -0.401038
# 4                 -0.132222             -0.060131                 -0.217669
# 5                 -0.116087             -0.003821                 -0.187551
# 6                 -0.159021             -0.174531                 -0.338359
# 7                 -0.135439             -0.268319                 -0.397191
# 8                 -0.088076             -0.244184                 -0.353549
# 9                 -0.215903             -0.309179                 -0.472893
# 10                -0.083013             -0.337908                 -0.449340
# 11                -0.137113             -0.332612                 -0.462447
# 12                -0.119448             -0.302203                 -0.417613
# 13                -0.152507             -0.249786                 -0.378520
# 14                -0.102793             -0.211084                 -0.289651
# 15                -0.037077             -0.274798                 -0.341366
# 16                -0.033385             -0.221420                 -0.349592
# 17                -0.036036             -0.162257                 -0.301636
# 18                -0.117315             -0.096643                 -0.233781
# 19                -0.131656             -0.064486                 -0.140439
# 20                -0.167512             -0.129068                 -0.276440
#
#     subject  activity
# 1         1   WALKING
# 2         1   WALKING
# 3         1   WALKING
# 4         1   WALKING
# 5         1   WALKING
# 6         1   WALKING
# 7         1   WALKING
# 8         1   WALKING
# 9         1   WALKING
# 10        1   WALKING
# 11        1   WALKING
# 12        1   WALKING
# 13        1   WALKING
# 14        1   WALKING
# 15        1   WALKING
# 16        1   WALKING
# 17        1   WALKING
# 18        1   WALKING
# 19        1   WALKING
# 20        1   WALKING
#
# [20 rows x 35 columns]

# %% [markdown]
# ### Note
# The dataset has 35 columns. In my first try i will try to create a neural network, that has 35 input nodes.
# Also the dataset has 6 labels, wich will be my output nodes.

# %%
len(df.columns)
# Out:
# 35

# %% [markdown]
# ### Creating the neural network

# %%
class neuralNetwork:
    #schon angepasst
    def __init__(self, inputnodes, hiddennodes1, hiddennodes2, outputnodes, learningrate):
        
        self.inodes = inputnodes
        self.hnodes1 = hiddennodes1
        self.hnodes2 = hiddennodes2
        self.onodes = outputnodes
        self.lr = learningrate
        
        #Gewichte für das Netz
        self.wih = numpy.random.normal(0.0, pow(self.hnodes1, -0.5), (self.hnodes1, self.inodes))
        self.whh = numpy.random.normal(0.0, pow(self.hnodes2, -0.5), (self.hnodes2, self.hnodes1))
        self.who = numpy.random.normal(0.0, pow(self.onodes, -0.5), (self.onodes, self.hnodes2))
        
        self.activation_function = lambda x: scipy.special.expit(x)
        pass
    
    def train(self, input_list, target_list):
        # convert input lists into 2d array
        inputs = numpy.array(input_list, ndmin=2).T
        targets = numpy.array(target_list, ndmin=2).T
        
        #calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        
        #calculate output from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        #caclulate inputs in final layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        
        #calculate outputs from final layer
        final_outputs = self.activation_function(final_inputs)
        
        #output layer error ( target-actual)
        output_errors = targets - final_outputs
        
        #hidden layer error is output_errors, split by weihgts recombined ar hidden nodes
        hidden_errors = numpy.dot(self.who.T, output_errors)
        
        #update the wheigts for the links between the hidden and output layers
        self.who += self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)), numpy.transpose(hidden_outputs))
        
        #update the wheigts for the links between hidden and input layers 
        self.wih += self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)), numpy.transpose(inputs))
        pass
    
    
    #Schon angepasst
    def query(self, input_list):
        #input array in 2d array
        inputs = numpy.array(input_list).T
        
        #signals in hidden layer 1
        hidden1_inputs = numpy.dot(self.wih, inputs)
        
        #emerging from hidden layer 1
        hidden1_outputs = self.activation_function(hidden1_inputs)
        
        #signals in hidden layer 2
        hidden2_inputs = numpy.dot(self.wih, hidden1_outputs)
        
        #emerging from hidden layer 2
        hidden2_outputs = self.activation_function(hidden2_inputs)
        
        
        #signals into final output layer
        final_inputs = numpy.dot(self.who, hidden2_outputs)
        
        #calculate the signals emerging from output layer
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs
        
        pass
