# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv("Server/TestData2/stayinghosentasche2.csv")

# %%
df2 = pd.read_csv("Server/TestData2/staying_data_hosentasche2.csv")

# %%
data_r = [df1,df2]
con_data = pd.concat(data_r)
con_data
# Out:
#       tbodyaccmeanx  tbodyaccmeany  tbodyaccmeanz  tgravityaccmeanx  \
# 0          0.048804       0.268735       9.817631          0.046823
# 1          0.048804       0.268735       9.817631          0.046823
# 2          0.048804       0.268735       9.817631          0.046823
# 3          0.048804       0.268735       9.817631          0.046823
# 4          0.048804       0.268735       9.817631          0.046823
# 5          0.373417      -9.718063      -1.003139          0.591819
# 6          0.273903      -0.826445       8.358972          0.048472
# 7          0.048804       0.268735       9.817631          0.046823
# 8          0.373417      -9.718063      -1.003139          0.591819
# 9          0.273903      -0.826445       8.358972          0.048472
# 10         0.048804       0.268735       9.817631          0.046823
# 11         0.373417      -9.718063      -1.003139          0.591819
# 12         0.048804       0.268735       9.817631          0.046823
# ...

# %%
print(len(df1))
print(len(df2))
print(len(con_data))
# Out:
# 2505
# 1219
# 3724

# %%
len(data)
# Out:
# 2

# %%
con_data.columns
# Out:
# Index(['tbodyaccmeanx', 'tbodyaccmeany', 'tbodyaccmeanz', 'tgravityaccmeanx',
#        'tgravityaccmeany', 'tgravityaccmeanz', 'tbodyaccjerkmeanx',
#        'tbodyaccjerkmeany', 'tbodyaccjerkmeanz', 'tbodygyromeanx',
#        'tbodygyromeany', 'tbodygyromeanz', 'tbodygyrojerkmeanx',
#        'tbodygyrojerkmeany', 'tbodygyrojerkmeanz', 'tbodyaccmagmean',
#        'tgravityaccmagmean', 'tbodyaccjerkmagmean', 'tbodygyromagmean',
#        'tbodygyrojerkmagmean'],
#       dtype='object')

# %% [markdown]
# ### Aktivitäten
# * 1 = Sitzen
# * 2 = Stehen

# %%
con_data['activity'] = 2

# %% [markdown]
# Am besten vor und nach den Stellen an denen die ganze Zeile nur 0 beinhaltet, ca. 20 Zeilen entfernen.

# %%
con_data.to_csv("Server/TestData2/TestDatalabeled/staying.csv")
